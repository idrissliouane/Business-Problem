# %% [markdown]
# ![png](Movies-ERD.png)

# %%
from sqlalchemy.engine import create_engine
import pymysql
pymysql.install_as_MySQLdb()
from urllib.parse import quote_plus
import pandas as pd

# %%
# Create the sqlalchemy engine and connection
username = "root"
password = "idrisjsk6" 
# password = quote_plus("Myp@ssword!") # Use the quote function if you have special chars in password
db_name = "movies"
connection = f"mysql+pymysql://{username}:{password}@localhost/{db_name}"
engine = create_engine(connection)
conn = engine.connect()

# %%
# Preview the names of all tables 
q = '''SHOW TABLES;'''
pd.read_sql(q, conn)
# Out:
#   Tables_in_movies
# 0           geners
# 1          ratings
# 2     title_basics
# 3     title_geners

# %%
q = '''DESCRIBE ratings;'''
describe = pd.read_sql(q, conn)
describe
# Out:
#              Field   Type Null  Key Default Extra
# 0           tconst    int   NO  PRI    None
# 1   average_rating  float  YES         None
# 2  number_of votes    int  YES         None

# %%
q = '''DESCRIBE title_basics;'''
describe = pd.read_sql(q, conn)
describe
# Out:
#            Field          Type Null  Key Default Extra
# 0         tconst           int   NO  PRI    None
# 1  primary_title  varchar(250)  YES         None
# 2     start_year           int  YES         None
# 3        runtime           int  YES         None

# %%
q = '''DESCRIBE title_geners ;'''
describe = pd.read_sql(q, conn)
describe
# Out:
#       Field Type Null Key Default Extra
# 0    tconst  int   NO        None
# 1  genre_id  int   NO        None

# %%
q = '''DESCRIBE geners;'''
describe = pd.read_sql(q, conn)
describe
# Out:
#         Field         Type Null  Key Default Extra
# 0    genre_id          int   NO  PRI    None
# 1  genre_name  varchar(55)  YES         None

# %%
basics = pd.read_csv(r'C:\Users\DELL\Documents\GitHub\Business-Problem\Data\filtered_movies_basics.csv')
basics.info()
basics.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 87077 entries, 0 to 87076
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   tconst          87077 non-null  object
#  1   titleType       87077 non-null  object
#  2   primaryTitle    87077 non-null  object
#  3   originalTitle   87077 non-null  object
#  4   isAdult         87077 non-null  int64
#  5   startYear       87077 non-null  float64
#  6   endYear         0 non-null      float64
#  7   runtimeMinutes  87077 non-null  int64
#  8   genres          87077 non-null  object
# dtypes: float64(2), int64(2), object(5)
# memory usage: 6.0+ MB
#       tconst titleType                                       primaryTitle  \
# 0  tt0035423     movie                                     Kate & Leopold
# 1  tt0062336     movie  The Tango of the Widower and Its Distorting Mi...
# 2  tt0069049     movie                         The Other Side of the Wind
# ...

# %%
basics['startYear'] = basics['startYear'].astype(int)

# %%
basics['tconst'] = basics['tconst'].str.replace('tt', '')

# %%
basics['tconst'] = basics['tconst'].astype(int)

# %%
ratings = pd.read_csv(r'C:\Users\DELL\Documents\GitHub\Business-Problem\Data\filtered_rated_movies_basics.csv')
ratings.info()
ratings.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 72705 entries, 0 to 72704
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   tconst         72705 non-null  object
#  1   averageRating  72705 non-null  float64
#  2   numVotes       72705 non-null  int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 1.7+ MB
#       tconst  averageRating  numVotes
# 0  tt0035423            6.4     89082
# 1  tt0062336            6.4       187
# 2  tt0069049            6.7      8044
# 3  tt0088751            5.2       350
# 4  tt0096056            5.5       878

# %%
ratings['tconst'] = ratings['tconst'].str.replace('tt', '')
ratings['tconst'] = ratings['tconst'].astype(int)

# %%
q = """SELECT @@FOREIGN_KEY_CHECKS"""
pd.read_sql(q, conn)
# Out:
#    @@FOREIGN_KEY_CHECKS
# 0                     1

# %%
q = """SET @@FOREIGN_KEY_CHECKS=0"""
conn.execute(q)

# %%
column_mapping = {
    'primaryTitle': 'primary_title',
    'startYear': 'start_year',
    'runtimeMinutes':'runtime'
}

# %%
basics_renamed = basics.rename(columns=column_mapping)

# %%
basics_renamed
# Out:
#         tconst titleType                                      primary_title  \
# 0        35423     movie                                     Kate & Leopold
# 1        62336     movie  The Tango of the Widower and Its Distorting Mi...
# 2        69049     movie                         The Other Side of the Wind
# 3        88751     movie                                  The Naked Monster
# 4        96056     movie                               Crime and Punishment
# ...        ...       ...                                                ...
# 87072  9914942     movie                             Life Without Sara Amat
# 87073  9915872     movie                               The Last White Witch
# 87074  9916170     movie                                      The Rehearsal
# 87075  9916190     movie                                          Safeguard
# 87076  9916362     movie                                              Coven
#
# ...

# %%
basics_renamed[['tconst','primary_title','start_year','runtime']].to_sql("title_basics",conn,index=False, if_exists='append')
# Out:
# 87077

# %%
ratings
# Out:
#         tconst  averageRating  numVotes
# 0        35423            6.4     89082
# 1        62336            6.4       187
# 2        69049            6.7      8044
# 3        88751            5.2       350
# 4        96056            5.5       878
# ...        ...            ...       ...
# 72700  9914942            6.7       207
# 72701  9915872            6.4         9
# 72702  9916170            7.0         7
# 72703  9916190            3.6       256
# 72704  9916362            6.4      5785
#
# [72705 rows x 3 columns]

# %%
column_rename = {'averageRating':'average_rating','numVotes':'number_of votes'}

# %%
ratings_renamed = ratings.rename(columns=column_rename)

# %%
ratings_renamed
# Out:
#         tconst  average_rating  number_of votes
# 0        35423             6.4            89082
# 1        62336             6.4              187
# 2        69049             6.7             8044
# 3        88751             5.2              350
# 4        96056             5.5              878
# ...        ...             ...              ...
# 72700  9914942             6.7              207
# 72701  9915872             6.4                9
# 72702  9916170             7.0                7
# 72703  9916190             3.6              256
# 72704  9916362             6.4             5785
#
# [72705 rows x 3 columns]

# %%
ratings_renamed.to_sql("ratings",conn,index=False, if_exists='append')
# Out:
# 72705

# %%
q = '''SHOW TABLES;'''
pd.read_sql(q, conn)
# Out:
#   Tables_in_movies
# 0           geners
# 1          ratings
# 2     title_basics
# 3     title_geners

# %%
q = '''SELECT * FROM ratings LIMIT 5'''
pd.read_sql(q, conn)
# Out:
#    tconst  average_rating  number_of votes
# 0   35423             6.4            89082
# 1   62336             6.4              187
# 2   69049             6.7             8044
# 3   88751             5.2              350
# 4   96056             5.5              878

# %%
q = '''SELECT * FROM title_basics LIMIT 5'''
pd.read_sql(q, conn)
# Out:
#    tconst                                      primary_title  start_year  \
# 0   35423                                     Kate & Leopold        2001
# 1   62336  The Tango of the Widower and Its Distorting Mi...        2020
# 2   69049                         The Other Side of the Wind        2018
# 3   88751                                  The Naked Monster        2005
# 4   96056                               Crime and Punishment        2002
#
#    runtime
# 0      118
# 1       70
# 2      122
# 3      100
# 4      126

# %%
q = '''DESCRIBE title_geners;'''
describe = pd.read_sql(q, conn)
describe
# Out:
#       Field Type Null Key Default Extra
# 0    tconst  int   NO        None
# 1  genre_id  int   NO        None

# %%
q = '''DESCRIBE geners;'''
describe = pd.read_sql(q, conn)
describe
# Out:
#         Field         Type Null  Key Default Extra
# 0    genre_id          int   NO  PRI    None
# 1  genre_name  varchar(55)  YES         None

# %%
q = '''DESCRIBE ratings;'''
describe = pd.read_sql(q, conn)
describe
# Out:
#              Field   Type Null  Key Default Extra
# 0           tconst    int   NO  PRI    None
# 1   average_rating  float  YES         None
# 2  number_of votes    int  YES         None

# %%
q = '''DESCRIBE title_basics;'''
describe = pd.read_sql(q, conn)
describe
# Out:
#            Field          Type Null  Key Default Extra
# 0         tconst           int   NO  PRI    None
# 1  primary_title  varchar(250)  YES         None
# 2     start_year           int  YES         None
# 3        runtime           int  YES         None
